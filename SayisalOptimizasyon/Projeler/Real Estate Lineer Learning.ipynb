# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("https://gist.githubusercontent.com/malibayram/3da1a1e08b5f49005ce731eae6f6806c/raw/6a1b0fcdf142bb1a6dc8fcf7f5264e8dc998a30e/House%2520Price%2520India%2520with%2520Notater.csv")

# %%
data
# Out:
#      Price  living_area_renov  Price per living_area_renov             Notater
# 0    4.175               1.39                   300.359712  Real Estate Expert
# 1   10.800               3.23                   334.365325               Other
# 2    3.700               1.62                   228.395062  Real Estate Expert
# 3    2.630               2.15                   122.325581               Other
# 4    3.350               1.41                   237.588652  Real Estate Expert
# ..     ...                ...                          ...                 ...
# 95   5.250               2.10                   250.000000  Real Estate Expert
# 96   3.270               1.50                   218.000000  Real Estate Expert
# 97   2.950               2.59                   113.899614               Other
# 98   4.350               2.19                   198.630137               Other
# 99   3.550               2.31                   153.679654               Other
#
# [100 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['Price', 'living_area_renov', 'Price per living_area_renov', 'Notater'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(data= data, x="living_area_renov",y="Price",hue="Notater")
# Out:
# <Axes: xlabel='living_area_renov', ylabel='Price'>

# %%
import numpy as np

# %%
np.random.seed(1)
weight=np.random.rand()
bias=np.random.rand()

# %%
def fiyat_tahmin(m2):
    global weight,bias
    return m2*weight+bias
def hata_payi(m2,fiyat):
    tahmin=fiyat_tahmin(m2)
    return fiyat-tahmin

# %%
plt.plot(data["living_area_renov"],fiyat_tahmin(data["living_area_renov"]),color="red")
sns.scatterplot(data= data, x="living_area_renov",y="Price",hue="Notater")
plt.show()

# %%
tahmin=fiyat_tahmin(data["living_area_renov"][0])
gercek=

tahmin,hata
# Out:
# (1.299985079978736, 2.875014920021264)

# %%
epoch=100
learning_rate=1e-3
tahmin=fiyat_tahmin(data["living_area_renov"][0])
hata=hata_payi(data["living_area_renov"][0],data["Price"][0])
weight=weight+learning_rate*hata * data.loc[0]["living_area_renov"]
bias=bias+learning_rate*hata
weight,bias
# Out:
# (3.0459227882626863, -1.053991828633836)

# %%
for j in range(epoch):
    for i in range(len(data)):
        tahmin=fiyat_tahmin(data["living_area_renov"][i])
        hata=hata_payi(data["living_area_renov"][i],data["Price"][i])
        weight=weight+learning_rate*hata * data.loc[i]["living_area_renov"]
        bias=bias+learning_rate*hata

    print(f"Epoch: {j}  , Weight: {weight}  , Bias: {bias}")
        
weight1=weight
bias1=bias
# Out:
# Epoch: 0  , Weight: 2.178036399486448  , Bias: 0.7818799780614164
# Epoch: 1  , Weight: 2.1989256687013428  , Bias: 0.7740733885013115
# Epoch: 2  , Weight: 2.2136319940711675  , Bias: 0.7635925299138902
# Epoch: 3  , Weight: 2.224761599574606  , Bias: 0.7516201425679357
# Epoch: 4  , Weight: 2.233813498727225  , Bias: 0.7388360657135399
# Epoch: 5  , Weight: 2.2416499418673768  , Bias: 0.7256309206632181
# Epoch: 6  , Weight: 2.2487669726029194  , Bias: 0.7122290009107681
# Epoch: 7  , Weight: 2.2554500261002453  , Bias: 0.69875894679257
# Epoch: 8  , Weight: 2.261863414398494  , Bias: 0.68529439079491
# Epoch: 9  , Weight: 2.268101789842273  , Bias: 0.6718773328393879
# Epoch: 10  , Weight: 2.2742197419522165  , Bias: 0.6585315834980107
# Epoch: 11  , Weight: 2.2802488187332135  , Bias: 0.6452704952283176
# Epoch: 12  , Weight: 2.2862073157177485  , Bias: 0.6321014086222231
# Epoch: 13  , Weight: 2.2921059056997786  , Bias: 0.6190282094440469
# ...

# %%
for j in range(epoch):
    for i in range(len(data)):
        tahmin=fiyat_tahmin(data["living_area_renov"][i])
        hata=hata_payi(data["living_area_renov"][i],data["Price"][i])
        notater=data.loc[i]["Notater"]
        notater_katsayisi=1
        if notater=="Real Estate Expert":
            notater_katsayisi=5
        elif notater=="other":
            notater_katsayisi=2
        weight=weight+learning_rate*hata * data.loc[i]["living_area_renov"]*notater_katsayisi
        bias=bias+learning_rate*hata

    print(f"Epoch: {j}  , Weight: {weight}  , Bias: {bias}")
# Out:
# Epoch: 0  , Weight: 1.60587196728494  , Bias: 0.9139703969430566
# Epoch: 1  , Weight: 1.9334170873869094  , Bias: 0.9650735092610891
# Epoch: 2  , Weight: 2.024330817962266  , Bias: 0.9770317881988029
# Epoch: 3  , Weight: 2.0502283974267277  , Bias: 0.9782514143800415
# Epoch: 4  , Weight: 2.0582573606070365  , Bias: 0.976536240580471
# Epoch: 5  , Weight: 2.061370498992875  , Bias: 0.9740300874775865
# Epoch: 6  , Weight: 2.0631263558266113  , Bias: 0.9713218082317296
# Epoch: 7  , Weight: 2.0645026124724284  , Bias: 0.9685730639917441
# Epoch: 8  , Weight: 2.0657679153172817  , Bias: 0.965828155213639
# Epoch: 9  , Weight: 2.0669961187289734  , Bias: 0.9630991409422255
# Epoch: 10  , Weight: 2.06820756191437  , Bias: 0.9603892234409748
# Epoch: 11  , Weight: 2.069407881607809  , Bias: 0.9576991725945863
# Epoch: 12  , Weight: 2.0705986749997827  , Bias: 0.955029090865053
# Epoch: 13  , Weight: 2.0717804291429722  , Bias: 0.9523788981681082
# ...

# %%
print(weight,learning_rate,hata_payi(data["living_area_renov"][0],data["Price"][0]),data.loc[0]["living_area_renov"])
# Out:
# 0.417022004702574 0.001 2.875014920021264 1.39

# %%
fiyat_tahmin(2.4)
# Out:
# 5.936393658326598

# %%
import matplotlib.pyplot as plt
import numpy as np

# Örnek veri
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Grafik oluştur
plt.plot(x, y, label='y = sin(x)')
plt.title('Sinüs Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.legend()

# Görüntüyü kaydet
plt.show()

# %%
y
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...
